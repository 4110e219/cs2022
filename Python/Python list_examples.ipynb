# %%
thislist = ["taiwan", "canada", "south korea"]
print(thislist)
# Out:
# ['taiwan', 'canada', 'south korea']

# %%
thislist = ["pencil", "paper", "ruler", "paper", "scissor"]
print(thislist[1])
print(thislist)
# Out:
# paper
# ['pencil', 'paper', 'ruler', 'paper', 'scissor']

# %%
thislist = ["taiwan", "canada", "south korea"]
print(len(thislist[2]))
# Out:
# 11

# %%
list1 = ["oppo", "samsung", "iphone"] 
list2 = [2, 4, 6, 8, 3]
list3 = [True, True, False]

print(list1)
print(list2)
print(list3)
# Out:
# ['oppo', 'samsung', 'iphone']
# [2, 4, 6, 8, 3]
# [True, True, False]

# %%
mylist = ["taiwan", "canada", "south korea"]

print(type(mylist))
# Out:
# <class 'list'>

# %%
thislist = list(("ghana", "almond", "joya"))
print(thislist)
# Out:
# ['ghana', 'almond', 'joya']

# %%
thislist = ["strawberry", "orange", "grapes"]
print(thislist[1])
# Out:
# orange

# %%
thislist = ["taiwan", "canada", "south korea"]
print(thislist[-3])
# Out:
# taiwan

# %%
thislist = ["grapes", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[1:6])

#This will return the items from position 1 to 6.

#Remember that the first item is position 0,
#and note that the item in position 6 is NOT included
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'melon']

# %%
thislist = ["grapes", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-5:-2])

#Negative indexing means starting from the end of the list.

#This example returns the items from index -5 (included) to index -2 (excluded)

#Remember that the last item has the index -2,
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist = ["taiwan", "canada", "south korea"]
if "taiwan" in thislist:
  print("Yes, 'taiwan' is in the country list")
# Out:
# Yes, 'taiwan' is in the country list

# %%
thislist = ["joana", "marie", "garcia"]
thislist[2] = "tirano"

print(thislist)
# Out:
# ['joana', 'marie', 'tirano']

# %%
thislist = ["grapes", "pineapple", "guava", "blueberry", "kiwi", "mango"]

thislist[1:3] = ["jackfruit", "avocado"]

print(thislist)
# Out:
# ['grapes', 'jackfruit', 'avocado', 'blueberry', 'kiwi', 'mango']

# %%
thislist = ["I", "love", "you", "much"]

thislist.insert(2, "so")

print(thislist)
# Out:
# ['I', 'love', 'so', 'you', 'much']

# %%
thislist = ["taiwan", "china", "USA"]

thislist.append("japan")

print(thislist)
# Out:
# ['taiwan', 'china', 'USA', 'japan']

# %%
thislist = ["shades", "brush", "haircomb"]
thislist.insert(1, "hairclip")
print(thislist)
# Out:
# ['shades', 'hairclip', 'brush', 'haircomb']

# %%
thislist = ["apple", "banana", "cherry"]
country = ["taiwan", "canada", "south korea"]

thislist.extend(country)

print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'taiwan', 'canada', 'south korea']

# %%
thislist = ["grapes", "strawberry", "guava"]
thistuple = ("kiwi", "orange")

thislist.extend(thistuple)

print(thislist)
# Out:
# ['grapes', 'strawberry', 'guava', 'kiwi', 'orange']

# %%
thislist = ["joana", "marie", "garcia"]
thislist.remove("marie")
print(thislist)
# Out:
# ['joana', 'garcia']

# %%
thislist = ["south korea", "japan", "taiwan"]
thislist.pop(2)
print(thislist)
# Out:
# ['south korea', 'japan']

# %%
thislist = ["pencil", "paper", "pen"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["sunlower", "daisy", "gumamela", "tulips", "rose"]

thislist.sort()

print(thislist)
# Out:
# ['daisy', 'gumamela', 'rose', 'sunlower', 'tulips']

# %%
thislist = [100, 50, 65, 82, 23]

thislist.sort()

print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = ["sunlower", "daisy", "gumamela", "tulips", "rose"]

thislist.sort(reverse = True)

print(thislist)
# Out:
# ['tulips', 'sunlower', 'rose', 'gumamela', 'daisy']

# %%
def myfunc(n):
  return abs(n - 19)

thislist = [100, 85, 77, 51, 19]

thislist.sort(key = myfunc)

print(thislist)
# Out:
# [19, 51, 77, 85, 100]

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]

thislist.sort()

print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
thislist = ["south korea", "japan", "taiwan", "USA"]

thislist.reverse()

print(thislist)
# Out:
# ['USA', 'taiwan', 'japan', 'south korea']

# %%
thislist = ["south korea", "japan", "taiwan"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['south korea', 'japan', 'taiwan']

# %%
thislist = ["south korea", "japan", "taiwan"]
mylist = list(thislist)
print(mylist)
# Out:
# ['south korea', 'japan', 'taiwan']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
fruits = ['strawberry', 'banana', 'cherry']

fruits.reverse()

print(fruits)
# Out:
# ['cherry', 'banana', 'strawberry']
