# %%
# names list
names = ['joana', 'grace', 'rogie', 'cleo', 'jamaica']

# 'rogie' is removed
names.remove('rogie')


# Updated names list
print('Updated names list: ', names)
# Out:
# Updated names list:  ['joana', 'grace', 'cleo', 'jamaica']

# %%
# colors list
colors = ['red', 'yellow', 'pink', 'green']

# Deleting 'violet' element
colors.remove('violet')


# Updated colors List
print('Updated colors list: ', colors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7a522ce223ee> in <module>
#       3
#       4 # Deleting 'violet' element
# ----> 5 colors.remove('violet')
#       6
#       7
#
# ValueError: list.remove(x): x not in list
